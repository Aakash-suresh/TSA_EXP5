# %% [markdown]
# <a href="https://colab.research.google.com/github/Aakash-suresh/TSA_EXP5/blob/main/TSA_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/time_series_data.csv')

# %%
data['date'] = pd.to_datetime(data['date'])
data.set_index('date', inplace=True)

# %%
period = 12

# %%
result = seasonal_decompose(data, model='additive', period=period)

# %%
plt.plot(result.trend)

# %%
plt.plot(result.seasonal)

# %%
plt.plot(result.resid)

# %%
# import pandas as pd
# import numpy as np

# # Generate a time series with trend and seasonality
# start_date = "2024-01-01"
# end_date = "2024-12-31"
# date_range = pd.date_range(start=start_date, end=end_date, freq='D')

# # Define trend and seasonality components
# trend = np.sin(np.linspace(0, 2*np.pi, num=len(date_range))) * 10
# seasonality = np.sin(np.linspace(0, 4*np.pi, num=len(date_range))) * 5

# # Add random noise
# noise = np.random.normal(loc=0, scale=2, size=len(date_range))

# # Combine components to create the time series
# data = trend + seasonality + noise

# # Scale the data to make values above 1
# data_scaled = data - min(data) + 1

# # Create DataFrame
# df = pd.DataFrame({'date': date_range, 'value': data_scaled})

# # Print the first few rows to verify
# print(df.head())

# # Save the DataFrame to a CSV file
# df.to_csv("time_series_data.csv", index=False)
